# %%
import shutil

# %%
shutil.move('football_players_detection_1/train',
            'football_players_detection_1/football_players_detection_1/train')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\shutil.py:874, in move(src, dst, copy_function)
#     873 try:
# --> 874     os.rename(src, real_dst)
#     875 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'football_players_detection_1/train' -> 'football_players_detection_1/football_players_detection_1/train\\train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 shutil.move('football_players_detection_1/train',
#       2             'football_players_detection_1/football_players_detection_1/train')
#       4 shutil.move('football_players_detection_1/test',
# ...

# %%
shutil.move('football_players_detection_1/test',
            'football_players_detection_1/football_players_detection_1/test')

shutil.move('football_players_detection_1/valid',
            'football_players_detection_1/football_players_detection_1/valid')
# Out:
# 'football_players_detection_1/football_players_detection_1/valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data='football_players_detection_1/data.yaml' epochs=100 imgsz=640
